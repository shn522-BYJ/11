# %% [markdown]
# <a href="https://colab.research.google.com/github/shn522-BYJ/example_repo/blob/main/what_a_waste7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive; drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load datasets
import pandas as pd
city_data = pd.read_csv("/content/city_level_data_0_0.csv", encoding='cp1252')
# Added encoding='latin-1' to handle the different file encoding
city_codebook = pd.read_csv("/content/city_level_codebook_0.csv", encoding='latin-1')

# %%
city_data
# Out:
#     iso3c region_id country_name income_id       city_name  \
# 0     AFG       SAS  Afghanistan       LIC       Jalalabad
# 1     AFG       SAS  Afghanistan       LIC        Kandahar
# 2     AFG       SAS  Afghanistan       LIC  Mazar-E-Sharif
# 3     AFG       SAS  Afghanistan       LIC           Kabul
# 4     AFG       SAS  Afghanistan       LIC       HiratÃ‚Â
# ..    ...       ...          ...       ...             ...
# 362   ZWE       SSF     Zimbabwe       LIC      HarareÃ‚Â
# 363   ZWE       SSF     Zimbabwe       LIC           Gweru
# 364   ZWE       SSF     Zimbabwe       LIC          Kariba
# 365   ZWE       SSF     Zimbabwe       LIC   Masvingo City
# 366   ZWE       SSF     Zimbabwe       LIC     SakubvaÃ‚Â
#
#     additional_data_annual_budget_for_waste_management_year  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
#
#     additional_data_annual_solid_waste_budget_year  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 362                                            NaN
# 363                                            NaN
# 364                                            NaN
# 365                                            NaN
# 366                                            NaN
#
#      additional_data_annual_swm_budget_2017_year  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 362                                          NaN
# 363                                          NaN
# 364                                          NaN
# 365                                          NaN
# 366                                          NaN
#
#      additional_data_annual_swm_budget_year  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 362                                     NaN
# 363                                     NaN
# 364                                     NaN
# 365                                     NaN
# 366                                     NaN
#
#      additional_data_annual_waste_budget_year  ...  \
# 0                                         NaN  ...
# 1                                         NaN  ...
# 2                                         NaN  ...
# 3                                         NaN  ...
# 4                                         NaN  ...
# ..                                        ...  ...
# 362                                       NaN  ...
# 363                                       NaN  ...
# 364                                       NaN  ...
# 365                                       NaN  ...
# 366                                       NaN  ...
#
#      waste_treatment_compost_percent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 362                              NaN
# 363                              NaN
# 364                              NaN
# 365                              NaN
# 366                              NaN
#
#      waste_treatment_controlled_landfill_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 362                                          NaN
# 363                                          NaN
# 364                                          NaN
# 365                                          NaN
# 366                                          NaN
#
#     waste_treatment_incineration_percent  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 362                                  NaN
# 363                                  NaN
# 364                                  NaN
# 365                                  NaN
# 366                                  NaN
#
#     waste_treatment_landfill_unspecified_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 362                                          NaN
# 363                                          NaN
# 364                                          NaN
# 365                                          NaN
# 366                                          NaN
#
#     waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# 0                               100.0                            NaN
# 1                               100.0                            NaN
# 2                               100.0                            NaN
# 3                                75.0                            NaN
# 4                               100.0                            NaN
# ..                                ...                            ...
# 362                               NaN                            NaN
# 363                               NaN                            NaN
# 364                               NaN                            NaN
# 365                               NaN                            NaN
# 366                               NaN                            NaN
#
#      waste_treatment_recycling_percent  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 362                                NaN
# 363                                NaN
# 364                                NaN
# 365                                NaN
# 366                                NaN
#
#      waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 362                                                NaN
# 363                                                NaN
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
#
#     waste_treatment_unaccounted_for_percent  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                      25.0
# 4                                       NaN
# ..                                      ...
# 362                                     NaN
# 363                                     NaN
# 364                                     NaN
# 365                                     NaN
# 366                                     NaN
#
#     waste_treatment_waterways_marine_percent
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 362                                      NaN
# 363                                      NaN
# 364                                      NaN
# 365                                      NaN
# 366                                      NaN
#
# [367 rows x 113 columns]

# %%
# Check for missing values
print(city_data.isnull().sum())
# Out:
# iso3c                                                              0
# region_id                                                          0
# country_name                                                       0
# income_id                                                          0
# city_name                                                          0
#                                                                 ...
# waste_treatment_other_percent                                    319
# waste_treatment_recycling_percent                                239
# waste_treatment_sanitary_landfill_landfill_gas_system_percent    312
# waste_treatment_unaccounted_for_percent                          246
# waste_treatment_waterways_marine_percent                         363
# Length: 113, dtype: int64

# %%
city_Newdata = city_data[["iso3c","region_id","country_name","city_name","income_id","population_population_number_of_people","total_msw_total_msw_generated_tons_year","waste_treatment_open_dump_percent","waste_treatment_recycling_percent"]].copy()
# Changed the tuple of column names to a list by enclosing it in square brackets []
# This will correctly select the desired columns and create a copy in city_Newdata
city_Newdata
# Out:
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 362   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 363   ZWE       SSF     Zimbabwe           Gweru       LIC
# 364   ZWE       SSF     Zimbabwe          Kariba       LIC
# 365   ZWE       SSF     Zimbabwe   Masvingo City       LIC
# 366   ZWE       SSF     Zimbabwe     SakubvaÃ‚Â        LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 362                               1379000.0
# 363                                157865.0
# 364                                 26512.0
# 365                                     NaN
# 366                                     NaN
#
#     total_msw_total_msw_generated_tons_year  \
# 0                                  58914.45
# 1                                    120971
# 2                                   52368.4
# 3                                   1989250
# 4                                   91644.7
# ..                                      ...
# 362                                352334.5
# 363                                 37887.6
# 364                                 7423.36
# 365                                     NaN
# 366                                     NaN
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent
# 0                                100.0                                NaN
# 1                                100.0                                NaN
# 2                                100.0                                NaN
# 3                                 75.0                                NaN
# 4                                100.0                                NaN
# ..                                 ...                                ...
# 362                                NaN                                NaN
# 363                                NaN                                NaN
# 364                                NaN                                NaN
# 365                                NaN                                NaN
# 366                                NaN                                NaN
#
# [367 rows x 9 columns]

# %%
# Check for missing values
print(city_Newdata.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# city_name                                    0
# income_id                                    0
# population_population_number_of_people      10
# total_msw_total_msw_generated_tons_year     41
# waste_treatment_open_dump_percent          266
# waste_treatment_recycling_percent          239
# dtype: int64

# %%
waste_summary = city_Newdata.groupby('region_id')[['waste_treatment_open_dump_percent', 'waste_treatment_recycling_percent']].mean()
print(waste_summary)
# Out:
#            waste_treatment_open_dump_percent  \
# region_id
# EAS                                78.836667
# ECS                                61.295455
# LCN                                37.074545
# MEA                                59.642857
# NAC                                      NaN
# SAS                                70.828421
# SSF                                70.616667
#
#            waste_treatment_recycling_percent
# region_id
# EAS                                16.733174
# ECS                                22.137103
# LCN                                11.925000
# MEA                                 9.661538
# NAC                                38.090000
# SAS                                10.551818
# SSF                                 8.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Population distribution
sns.histplot(city_Newdata['population_population_number_of_people'], kde=True)
plt.title('City Population Distribution')
plt.show()

# Waste treatment percentages by income group
waste_cols = ['waste_treatment_open_dump_percent', 'waste_treatment_recycling_percent']
city_Newdata.groupby('income_id')[waste_cols].mean().plot(kind='bar')
plt.title('Waste Treatment by Income Group')
plt.show()

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
fig = px.bar(city_Newdata, x='region_id', y='waste_treatment_open_dump_percent', color='income_id')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9d9bf8a2-9a42-4871-8477-3766c7d48f67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d9bf8a2-9a42-4871-8477-3766c7d48f67")) {                    Plotly.newPlot(                        "9d9bf8a2-9a42-4871-8477-3766c7d48f67",                        [{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["SAS","SAS","SAS","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","LCN","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","MEA","SSF","ECS","ECS","SSF","SSF","SSF","SSF","MEA","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF"],"xaxis":"x","y":[100.0,100.0,100.0,75.0,100.0,100.0,null,100.0,100.0,null,null,null,null,10.0,null,null,null,null,null,null,null,null,null,null,100.0,null,null,null,null,null,null,null,null,null,99.0,null,null,37.4,null,null,null,19.65,null,null,100.0,25.4,null,null,85.7,86.5,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,24.0,null,null,null,null,null,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["SSF","SAS","SAS","SAS","SAS","SAS","LCN","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","MEA","MEA","EAS","ECS","SSF","SSF","LCN","LCN","EAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SSF","SSF","ECS","ECS","EAS","EAS","EAS","SAS","SAS","SAS","SAS","SAS","SAS","MEA","MEA","MEA","ECS","ECS","EAS","EAS","EAS","SSF","SSF","SSF","SSF","SSF","SSF","LCN","LCN","SAS","SAS","SAS","EAS","EAS","EAS","MEA","EAS","LCN","EAS","MEA","MEA","MEA","ECS","ECS","ECS","ECS","EAS","EAS","EAS","ECS","ECS","SSF","SSF"],"xaxis":"x","y":[null,55.45,29.17,27.16,43.5,67.29,null,null,82.0,null,null,null,null,null,null,null,null,null,null,null,null,5.0,null,null,100.0,60.0,60.0,100.0,100.0,65.7,null,null,100.0,50.0,15.0,54.0,81.0,null,92.0,70.0,null,null,100.0,90.0,60.0,45.0,30.0,null,null,100.0,null,12.0,97.0,null,null,13.3,100.0,60.0,null,76.0,74.0,null,25.0,null,null,54.0,75.0,60.0,100.0,null,93.0,100.0,33.0,100.0,null,null,null,null,92.2,80.4,61.5,70.3,null,99.0,null,100.0,null,null,null,null,87.66,88.85,null,null,null,null,null,44.0,null,null,null,null,25.0,60.0,null,null,null,null,null,null,4.0,null,null,null,null,null,null,null,null,null,null,10.0,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["ECS","ECS","ECS","ECS","EAS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","LCN","LCN","LCN","LCN","LCN","SSF", ...

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
#fig = px.bar(city_Newdata, x='city_name', y='waste_treatment_open_dump_percent', color='income_id')
#fig.show()

# %%
import plotly.express as px

# Sort the data by 'waste_treatment_recycling_percent' in descending order
sorted_data = city_Newdata.sort_values(by='waste_treatment_open_dump_percent', ascending=False)

# Select the top 10 cities
top_10_cities = sorted_data.head(10)

# Create the bar chart
fig = px.bar(
    top_10_cities,
    x='city_name',
    y='waste_treatment_open_dump_percent',
    color='income_id',
    title='Top 10 Cities by Waste Treatment Open dump Percentage',
    labels={'waste_treatment_open_dump_percent': 'Open dump (%)'},
)

# Customize the layout
fig.update_layout(
    xaxis_title="City Name",
    yaxis_title="Open dump (%)",
    xaxis=dict(tickangle=45, categoryorder='total descending'),  # Ensure sorted order is preserved
    showlegend=True,
    template="plotly_white"
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da981ef0-9f80-4415-86de-8cc2276c43ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da981ef0-9f80-4415-86de-8cc2276c43ee")) {                    Plotly.newPlot(                        "da981ef0-9f80-4415-86de-8cc2276c43ee",                        [{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003ecity_name=%{x}\u003cbr\u003eOpen dump (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["Jalalabad","Kandahar"],"xaxis":"x","y":[100.0,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003ecity_name=%{x}\u003cbr\u003eOpen dump (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["Baghdad"],"xaxis":"x","y":[100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003ecity_name=%{x}\u003cbr\u003eOpen dump (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["Kota","Tirunelveli","Amritsar","Leh","Rajkot","Cuttack","Bhubaneswar"],"xaxis":"x","y":[100.0,100.0,100.0,100.0,100.0,100.0,100.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
fig = px.bar(city_Newdata, x='region_id', y='waste_treatment_recycling_percent', color='income_id')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0689865-4951-4142-b61f-d5a32ba89c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0689865-4951-4142-b61f-d5a32ba89c29")) {                    Plotly.newPlot(                        "e0689865-4951-4142-b61f-d5a32ba89c29",                        [{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["SAS","SAS","SAS","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","LCN","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","MEA","SSF","ECS","ECS","SSF","SSF","SSF","SSF","MEA","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,21.0,null,1.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,13.0,null,null,null,12.0,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["SSF","SAS","SAS","SAS","SAS","SAS","LCN","SAS","SAS","SSF","SSF","SSF","SSF","SSF","SSF","MEA","MEA","EAS","ECS","SSF","SSF","LCN","LCN","EAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SAS","SSF","SSF","ECS","ECS","EAS","EAS","EAS","SAS","SAS","SAS","SAS","SAS","SAS","MEA","MEA","MEA","ECS","ECS","EAS","EAS","EAS","SSF","SSF","SSF","SSF","SSF","SSF","LCN","LCN","SAS","SAS","SAS","EAS","EAS","EAS","MEA","EAS","LCN","EAS","MEA","MEA","MEA","ECS","ECS","ECS","ECS","EAS","EAS","EAS","ECS","ECS","SSF","SSF"],"xaxis":"x","y":[null,4.55,12.41,4.84,13.5,4.71,4.0,null,5.0,null,null,null,null,null,null,null,null,null,null,5.0,null,3.0,null,7.5,null,null,null,null,null,null,null,21.6,null,11.17,null,null,null,15.0,null,null,18.8,8.0,null,3.7,null,null,null,null,null,null,15.0,null,null,null,null,15.0,null,null,null,null,null,null,null,20.0,null,null,null,null,null,22.0,1.66,null,5.0,null,1.0,null,1.0,10.0,3.4,14.2,4.1,10.4,3.1,null,3.0,null,null,null,null,5.0,4.33,3.2,null,null,null,null,null,null,null,8.95,null,null,null,null,42.0,1.7,null,null,null,null,3.0,2.0,6.0,null,6.4,null,null,8.2,null,null,0.0,10.0,null,6.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["ECS","ECS","ECS","ECS","EAS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","LCN","LCN","LCN","LCN","LCN","SSF","EAS","LCN","LCN","LCN","LCN","LCN","LCN","LCN", ...

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
#fig = px.bar(city_Newdata, x='city_name', y='waste_treatment_recycling_percent', color='income_id')
#fig.show()

# %%
import plotly.express as px

# Sort the data by 'waste_treatment_recycling_percent' in descending order
sorted_data = city_Newdata.sort_values(by='waste_treatment_recycling_percent', ascending=False)

# Select the top 10 cities
top_10_cities = sorted_data.head(10)

# Create the bar chart
fig = px.bar(
    top_10_cities,
    x='city_name',
    y='waste_treatment_recycling_percent',
    color='income_id',
    title='Top 10 Cities by Waste Treatment Recycling Percentage',
    labels={'waste_treatment_recycling_percent': 'Recycling Percentage (%)'},
)

# Customize the layout
fig.update_layout(
    xaxis_title="City Name",
    yaxis_title="Recycling Percentage (%)",
    xaxis=dict(tickangle=45, categoryorder='total descending'),  # Ensure sorted order is preserved
    showlegend=True,
    template="plotly_white"
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51f0f60b-a1ce-413b-a3a2-1b36d1b3421a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51f0f60b-a1ce-413b-a3a2-1b36d1b3421a")) {                    Plotly.newPlot(                        "51f0f60b-a1ce-413b-a3a2-1b36d1b3421a",                        [{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003ecity_name=%{x}\u003cbr\u003eRecycling Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["San JosÃƒÂ©"],"xaxis":"x","y":[94.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=HIC\u003cbr\u003ecity_name=%{x}\u003cbr\u003eRecycling Percentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HIC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"HIC","offsetgroup":"HIC","orientation":"v","showlegend":true,"textposition":"auto","x":["Parma","Canberra","Ljubljana","Seattle","Liege","Milano","Dublin","Toronto","Bergen"],"xaxis":"x","y":[72.0,70.0,61.0,58.04,53.0,49.9,49.0,47.91,46.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444 ...

# %%
city_Newdata1 = city_data[["iso3c","region_id","country_name","city_name","income_id","population_population_number_of_people","total_msw_total_msw_generated_tons_year","waste_treatment_open_dump_percent","waste_treatment_recycling_percent"]].copy()
# Changed the tuple of column names to a list by enclosing it in square brackets []
# This will correctly select the desired columns and create a copy in city_Newdata
city_Newdata1
# Out:
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 362   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 363   ZWE       SSF     Zimbabwe           Gweru       LIC
# 364   ZWE       SSF     Zimbabwe          Kariba       LIC
# 365   ZWE       SSF     Zimbabwe   Masvingo City       LIC
# 366   ZWE       SSF     Zimbabwe     SakubvaÃ‚Â        LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 362                               1379000.0
# 363                                157865.0
# 364                                 26512.0
# 365                                     NaN
# 366                                     NaN
#
#     total_msw_total_msw_generated_tons_year  \
# 0                                  58914.45
# 1                                    120971
# 2                                   52368.4
# 3                                   1989250
# 4                                   91644.7
# ..                                      ...
# 362                                352334.5
# 363                                 37887.6
# 364                                 7423.36
# 365                                     NaN
# 366                                     NaN
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent
# 0                                100.0                                NaN
# 1                                100.0                                NaN
# 2                                100.0                                NaN
# 3                                 75.0                                NaN
# 4                                100.0                                NaN
# ..                                 ...                                ...
# 362                                NaN                                NaN
# 363                                NaN                                NaN
# 364                                NaN                                NaN
# 365                                NaN                                NaN
# 366                                NaN                                NaN
#
# [367 rows x 9 columns]

# %%
# Check for missing values
print(city_Newdata1.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# city_name                                    0
# income_id                                    0
# population_population_number_of_people      10
# total_msw_total_msw_generated_tons_year     41
# waste_treatment_open_dump_percent          266
# waste_treatment_recycling_percent          239
# dtype: int64

# %%
city_total_data = city_Newdata1.dropna(subset=["total_msw_total_msw_generated_tons_year"], inplace=False)
# Changed the first argument to subset=["total_msw_total_msw_generated_tons_year"]
# This will drop rows where "total_msw_total_msw_generated_tons_year" has missing values
city_total_data
# Out:
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 360   ZWE       SSF     Zimbabwe          Norton       LIC
# 361   ZWE       SSF     Zimbabwe        Chinhoyi       LIC
# 362   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 363   ZWE       SSF     Zimbabwe           Gweru       LIC
# 364   ZWE       SSF     Zimbabwe          Kariba       LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 360                                 58421.0
# 361                                 98000.0
# 362                               1379000.0
# 363                                157865.0
# 364                                 26512.0
#
#     total_msw_total_msw_generated_tons_year  \
# 0                                  58914.45
# 1                                    120971
# 2                                   52368.4
# 3                                   1989250
# 4                                   91644.7
# ..                                      ...
# 360                                14021.04
# 361                                   25480
# 362                                352334.5
# 363                                 37887.6
# 364                                 7423.36
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent
# 0                                100.0                                NaN
# 1                                100.0                                NaN
# 2                                100.0                                NaN
# 3                                 75.0                                NaN
# 4                                100.0                                NaN
# ..                                 ...                                ...
# 360                                NaN                                NaN
# 361                                NaN                                NaN
# 362                                NaN                                NaN
# 363                                NaN                                NaN
# 364                                NaN                                NaN
#
# [326 rows x 9 columns]

# %%
city_total_data["total_msw_total_msw_generated_tons_year"] = pd.to_numeric(city_total_data["total_msw_total_msw_generated_tons_year"], errors='coerce')
city_total_data["population_population_number_of_people"] = pd.to_numeric(city_total_data["population_population_number_of_people"], errors='coerce')
city_total_data["msw per capita"] = city_total_data["total_msw_total_msw_generated_tons_year"] / city_total_data["population_population_number_of_people"]
city_total_data
# Out:
# <ipython-input-240-f83d7ad1bad8>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-240-f83d7ad1bad8>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-240-f83d7ad1bad8>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 360   ZWE       SSF     Zimbabwe          Norton       LIC
# 361   ZWE       SSF     Zimbabwe        Chinhoyi       LIC
# 362   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 363   ZWE       SSF     Zimbabwe           Gweru       LIC
# 364   ZWE       SSF     Zimbabwe          Kariba       LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 360                                 58421.0
# 361                                 98000.0
# 362                               1379000.0
# 363                                157865.0
# 364                                 26512.0
#
#      total_msw_total_msw_generated_tons_year  \
# 0                                   58914.45
# 1                                  120971.00
# 2                                   52368.40
# 3                                 1989250.00
# 4                                   91644.70
# ..                                       ...
# 360                                 14021.04
# 361                                 25480.00
# 362                                352334.50
# 363                                 37887.60
# 364                                  7423.36
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent  \
# 0                                100.0                                NaN
# 1                                100.0                                NaN
# 2                                100.0                                NaN
# 3                                 75.0                                NaN
# 4                                100.0                                NaN
# ..                                 ...                                ...
# 360                                NaN                                NaN
# 361                                NaN                                NaN
# 362                                NaN                                NaN
# 363                                NaN                                NaN
# 364                                NaN                                NaN
#
#      msw per capita
# 0          0.180395
# 1          0.281984
# 2          0.082437
# 3          0.537635
# 4          0.271943
# ..              ...
# 360        0.240000
# 361        0.260000
# 362        0.255500
# 363        0.240000
# 364        0.280000
#
# [325 rows x 10 columns]

# %%
# Check for missing values
print(city_total_data.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# city_name                                    0
# income_id                                    0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          227
# waste_treatment_recycling_percent          201
# msw per capita                               0
# dtype: int64

# %%
city_total_data = city_total_data.dropna(subset=["total_msw_total_msw_generated_tons_year"], inplace=False)
# Changed the first argument to subset=["total_msw_total_msw_generated_tons_year"]
# This will drop rows where "total_msw_total_msw_generated_tons_year" has missing values
city_total_data
# Out:
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 360   ZWE       SSF     Zimbabwe          Norton       LIC
# 361   ZWE       SSF     Zimbabwe        Chinhoyi       LIC
# 362   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 363   ZWE       SSF     Zimbabwe           Gweru       LIC
# 364   ZWE       SSF     Zimbabwe          Kariba       LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 360                                 58421.0
# 361                                 98000.0
# 362                               1379000.0
# 363                                157865.0
# 364                                 26512.0
#
#      total_msw_total_msw_generated_tons_year  \
# 0                                   58914.45
# 1                                  120971.00
# 2                                   52368.40
# 3                                 1989250.00
# 4                                   91644.70
# ..                                       ...
# 360                                 14021.04
# 361                                 25480.00
# 362                                352334.50
# 363                                 37887.60
# 364                                  7423.36
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent  \
# 0                                100.0                                NaN
# 1                                100.0                                NaN
# 2                                100.0                                NaN
# 3                                 75.0                                NaN
# 4                                100.0                                NaN
# ..                                 ...                                ...
# 360                                NaN                                NaN
# 361                                NaN                                NaN
# 362                                NaN                                NaN
# 363                                NaN                                NaN
# 364                                NaN                                NaN
#
#      msw per capita
# 0          0.180395
# 1          0.281984
# 2          0.082437
# 3          0.537635
# 4          0.271943
# ..              ...
# 360        0.240000
# 361        0.260000
# 362        0.255500
# 363        0.240000
# 364        0.280000
#
# [325 rows x 10 columns]

# %%
# Check for missing values
print(city_total_data.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# city_name                                    0
# income_id                                    0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          227
# waste_treatment_recycling_percent          201
# msw per capita                               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Convert the 'total_msw_total_msw_generated_tons_year' column to numeric type before using nlargest
city_total_data["total_msw_total_msw_generated_tons_year"] = pd.to_numeric(city_total_data["total_msw_total_msw_generated_tons_year"], errors='coerce')

# Filter the top 10 cities based on total waste generated
#cities = city_total_data.nlargest(326, "total_msw_total_msw_generated_tons_year")
top_cities = city_total_data.nlargest(10, "total_msw_total_msw_generated_tons_year")
# Dynamically adjust the figure size based on the number of cities
plt.figure(figsize=(max(15, len(top_cities) / 2), 8))  # Adjust width dynamically

# Plot the bar chart
plt.bar(top_cities["city_name"], top_cities["total_msw_total_msw_generated_tons_year"], color='orange')

# Customize the plot
plt.xticks(rotation=90, fontsize=10)  # Rotate X-axis labels for better readability
plt.xlabel("City Name", fontsize=14)
plt.ylabel("Total MSW Generated (tons/Year)", fontsize=14)
plt.title("Waste Generated by Top 10 Cities", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Convert the 'total_msw_total_msw_generated_tons_year' column to numeric type before using nlargest
city_total_data["msw per capita"] = pd.to_numeric(city_total_data["msw per capita"], errors='coerce')

# Filter the top 10 cities based on total waste generated
#cities = city_total_data.nlargest(326, "total_msw_total_msw_generated_tons_year")
top_cities = city_total_data.nlargest(10, "msw per capita")
# Dynamically adjust the figure size based on the number of cities
plt.figure(figsize=(max(15, len(top_cities) / 2), 8))  # Adjust width dynamically

# Plot the bar chart
plt.bar(top_cities["city_name"], top_cities["msw per capita"], color='grey')

# Customize the plot
plt.xticks(rotation=90, fontsize=10)  # Rotate X-axis labels for better readability
plt.xlabel("City Name", fontsize=14)
plt.ylabel("MSW per capita (tons/Year)", fontsize=14)
plt.title("Waste per capita Generated by Top 10 Cities", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %%
city_codebook
# Out:
#     regionID iso3c        country_name       city_name incomeID  \
# 0        SAS   AFG         Afghanistan       Jalalabad      LIC
# 1        SAS   IND               India  Vishakhapatnam      LMC
# 2        LCN   COL            Colombia            Cali      UMC
# 3        SAS   AFG         Afghanistan           Kabul      LIC
# 4        SAS   AFG         Afghanistan          Hirat?      LIC
# ..       ...   ...                 ...             ...      ...
# 679      SSF   ZWE            Zimbabwe           Gweru      LIC
# 680      SSF   ZWE            Zimbabwe        HarareÂ       LIC
# 681      ECS   RUS  Russian Federation        Kemerovo      UMC
# 682      SSF   ZWE            Zimbabwe        Chinhoyi      LIC
# 683      SSF   ZWE            Zimbabwe          Kariba      LIC
#
#                                  measurement        units    year  \
# 0     population_population_number_of_people  # of people  2015.0
# 1     population_population_number_of_people  # of people  2011.0
# 2     population_population_number_of_people  # of people  2005.0
# 3     population_population_number_of_people  # of people  2016.0
# 4     population_population_number_of_people  # of people  2015.0
# ..                                       ...          ...     ...
# 679  total_msw_total_msw_generated_tons_year  tonnes/year  2014.0
# 680  total_msw_total_msw_generated_tons_year  tonnes/year  2000.0
# 681  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 682  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 683  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
#
#                                                 source  \
# 0    Islamic Republic of Afghanistan. 2015. "State ...
# 1    Census of India. 2014. "Databook for PC 2011."...
# 2    CCAC (Climate and Clean Air Coalition). n.d.(d...
# 3    World Bank. 2016b. "Islamic Â Republic of Afgh...
# 4    UN DESA (United Nations, Department of Economi...
# ..                                                 ...
# 679  GIZ (Deutsche Gesellschaft fÃ¼r Internationale...
# 680  Achankeng, Eric. 2003. "Globalization, Urbaniz...
# 681  Evgenievna, Bannikova Anastasia. 2017. "Develo...
# 682  GIZ (Deutsche Gesellschaft fÃ¼r Internationale...
# 683  GIZ (Deutsche Gesellschaft fÃ¼r Internationale...
#
#                                              comments  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 679                            1 (0.24 kg/person/day)
# 680                             1 (0.7 kg/person/day)
# 681   Nature Management and Environmental Engineering
# 682                            1 (0.26 kg/person/day)
# 683                            1 (0.28 kg/person/day)
#
#                                            Unnamed: 10
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 679                                                NaN
# 680                                                NaN
# 681   Tomsk STate University. Ministry of Education...
# 682                                                NaN
# 683                                                NaN
#
# [684 rows x 11 columns]

# %%
city_Newcodebook = city_codebook.iloc[:,0:8]
city_Year_codebook = city_Newcodebook.dropna(subset=["year"])
tonnes_data = city_Year_codebook[city_Year_codebook['units'] == 'tonnes/year']
city_Year_codebook['year'] = city_Year_codebook['year'].astype(int)
tonnes_data
# Out:
# <ipython-input-170-b49e1e3c95fc>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     regionID iso3c        country_name    city_name incomeID  \
# 358      ECS   EST             Estonia      Tallinn      HIC
# 359      LCN   BLZ              Belize  Belize City      UMC
# 360      SAS   AFG         Afghanistan     Kandahar      LIC
# 361      SSF   BWA            Botswana     Gaborone      UMC
# 362      ECS   HRV             Croatia       Zagreb      UMC
# ..       ...   ...                 ...          ...      ...
# 679      SSF   ZWE            Zimbabwe        Gweru      LIC
# 680      SSF   ZWE            Zimbabwe     HarareÂ       LIC
# 681      ECS   RUS  Russian Federation     Kemerovo      UMC
# 682      SSF   ZWE            Zimbabwe     Chinhoyi      LIC
# 683      SSF   ZWE            Zimbabwe       Kariba      LIC
#
#                                  measurement        units    year
# 358  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 359  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# 360  total_msw_total_msw_generated_tons_year  tonnes/year  2017.0
# 361  total_msw_total_msw_generated_tons_year  tonnes/year  2011.0
# 362  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# ..                                       ...          ...     ...
# 679  total_msw_total_msw_generated_tons_year  tonnes/year  2014.0
# 680  total_msw_total_msw_generated_tons_year  tonnes/year  2000.0
# 681  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 682  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 683  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
#
# [326 rows x 8 columns]

# %%
import pandas as pd

# Example: Rename columns in `tonnes_data` to match `city_com_data`
tonnes_data.rename(columns={
    "regionID": "region_id",
    "incomeID": "income_id"
}, inplace=True)

# Perform the merge on common columns
merged_data = pd.merge(
    city_total_data,
    tonnes_data[["city_name", "year"]],  # Only keep necessary columns from tonnes_data
    how="left",  # Left join to keep all rows from city_com_data
    on="city_name"  # Merge on city_name
)

# Check the resulting table
merged_data
# Out:
# <ipython-input-223-05d048a36762>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 4     AFG       SAS  Afghanistan       HiratÃ‚Â        LIC
# ..    ...       ...          ...             ...       ...
# 321   ZWE       SSF     Zimbabwe          Norton       LIC
# 322   ZWE       SSF     Zimbabwe        Chinhoyi       LIC
# 323   ZWE       SSF     Zimbabwe      HarareÃ‚Â        LIC
# 324   ZWE       SSF     Zimbabwe           Gweru       LIC
# 325   ZWE       SSF     Zimbabwe          Kariba       LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 4                                  337000.0
# ..                                      ...
# 321                                 58421.0
# 322                                 98000.0
# 323                               1379000.0
# 324                                157865.0
# 325                                 26512.0
#
#      total_msw_total_msw_generated_tons_year  msw per capita    year
# 0                                   58914.45        0.180395  2017.0
# 1                                  120971.00        0.281984  2017.0
# 2                                   52368.40        0.082437  2017.0
# 3                                 1989250.00        0.537635  2016.0
# 4                                   91644.70        0.271943     NaN
# ..                                       ...             ...     ...
# 321                                 14021.04        0.240000  2012.0
# 322                                 25480.00        0.260000  2012.0
# 323                                352334.50        0.255500     NaN
# 324                                 37887.60        0.240000  2014.0
# 325                                  7423.36        0.280000  2012.0
#
# [326 rows x 9 columns]

# %%
# Check for missing values
print(merged_data.isnull().sum())
# Out:
# iso3c                                       0
# region_id                                   0
# country_name                                0
# city_name                                   0
# income_id                                   0
# population_population_number_of_people      0
# total_msw_total_msw_generated_tons_year     1
# msw per capita                              1
# year                                       22
# dtype: int64

# %%
# Drop rows with missing 'year'
city_com = merged_data.dropna(subset=["year","total_msw_total_msw_generated_tons_year"],inplace=False)

# Check the size of the resulting DataFrame
print(f"Original data size: {merged_data.shape}")
print(f"Filtered data size: {city_com.shape}")

# Verify if all 'year' values are now valid
print(city_com["year"].isnull().sum())  # Should print 0
# Out:
# Original data size: (326, 9)
# Filtered data size: (303, 9)
# 0

# %%
# Check for missing values
print(city_com.isnull().sum())
# Out:
# iso3c                                      0
# region_id                                  0
# country_name                               0
# city_name                                  0
# income_id                                  0
# population_population_number_of_people     0
# total_msw_total_msw_generated_tons_year    0
# msw per capita                             0
# year                                       0
# dtype: int64

# %%
# Drop rows where "year" is NaN
city_com_codebook = city_com.dropna(subset=["year"])

# Convert the "year" column to integers
city_com_codebook['year'] = city_com_codebook['year'].astype(int)
city_com_codebook
# Out:
#     iso3c region_id country_name       city_name income_id  \
# 0     AFG       SAS  Afghanistan       Jalalabad       LIC
# 1     AFG       SAS  Afghanistan        Kandahar       LIC
# 2     AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3     AFG       SAS  Afghanistan           Kabul       LIC
# 5     AGO       SSF       Angola          Luanda       LMC
# ..    ...       ...          ...             ...       ...
# 320   ZMB       SSF       Zambia          Lusaka       LMC
# 321   ZWE       SSF     Zimbabwe          Norton       LIC
# 322   ZWE       SSF     Zimbabwe        Chinhoyi       LIC
# 324   ZWE       SSF     Zimbabwe           Gweru       LIC
# 325   ZWE       SSF     Zimbabwe          Kariba       LIC
#
#      population_population_number_of_people  \
# 0                                  326585.0
# 1                                  429000.0
# 2                                  635250.0
# 3                                 3700000.0
# 5                                 4508000.0
# ..                                      ...
# 320                               1719000.0
# 321                                 58421.0
# 322                                 98000.0
# 324                                157865.0
# 325                                 26512.0
#
#      total_msw_total_msw_generated_tons_year  msw per capita  year
# 0                                   58914.45        0.180395  2017
# 1                                  120971.00        0.281984  2017
# 2                                   52368.40        0.082437  2017
# 3                                 1989250.00        0.537635  2016
# 5                                 1316336.00        0.292000  2009
# ..                                       ...             ...   ...
# 320                                530000.00        0.308319  2011
# 321                                 14021.04        0.240000  2012
# 322                                 25480.00        0.260000  2012
# 324                                 37887.60        0.240000  2014
# 325                                  7423.36        0.280000  2012
#
# [303 rows x 9 columns]

# %%
# Trend analysis for a specific metric
yearly_trend = city_com_codebook.groupby('year')['waste_treatment_open_dump_percent'].mean()
yearly_trend.plot()
plt.title('City Waste Treatment open_dump Trends Over Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-228-a8649dbd1445> in <cell line: 2>()
#       1 # Trend analysis for a specific metric
# ----> 2 yearly_trend = city_com_codebook.groupby('year')['waste_treatment_open_dump_percent'].mean()
#       3 yearly_trend.plot()
#       4 plt.title('City Waste Treatment open_dump Trends Over Time')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: waste_treatment_open_dump_percent'

# %%
# Trend analysis for a specific metric
yearly_trend = city_com_codebook.groupby('year')['waste_treatment_recycling_percent'].mean()
yearly_trend.plot()
plt.title('City Waste Treatment recycling Trends Over Time')
plt.show()

# %%
# Load datasets
country_data = pd.read_csv("/content/country_level_data.csv", encoding='cp1252')
# Added encoding='latin-1' to handle the different file encoding
country_codebook = pd.read_csv("/content/country_level_codebook.csv", encoding='latin-1')

# %%
# Check for missing values
print(country_data.isnull().sum())
# Out:
# iso3c                                                                                      0
# region_id                                                                                  0
# country_name                                                                               1
# income_id                                                                                  0
# gdp                                                                                        1
# composition_food_organic_waste_percent                                                    41
# composition_glass_percent                                                                 46
# composition_metal_percent                                                                 46
# composition_other_percent                                                                 42
# composition_paper_cardboard_percent                                                       41
# composition_plastic_percent                                                               42
# composition_rubber_leather_percent                                                       164
# composition_wood_percent                                                                 153
# composition_yard_garden_green_waste_percent                                              179
# other_information_information_system_for_solid_waste_management                          109
# other_information_national_agency_to_enforce_solid_waste_laws_and_regulations             54
# other_information_national_law_governing_solid_waste_management_in_the_country            23
# other_information_ppp_rules_and_regulations                                               59
# other_information_summary_of_key_solid_waste_information_made_available_to_the_public    145
# population_population_number_of_people                                                     0
# special_waste_agricultural_waste_tons_year                                               163
# special_waste_construction_and_demolition_waste_tons_year                                144
# special_waste_e_waste_tons_year                                                           36
# special_waste_hazardous_waste_tons_year                                                   99
# special_waste_industrial_waste_tons_year                                                 176
# special_waste_medical_waste_tons_year                                                    112
# total_msw_total_msw_generated_tons_year                                                    2
# waste_collection_coverage_rural_percent_of_geographic_area                               216
# waste_collection_coverage_rural_percent_of_households                                    208
# waste_collection_coverage_rural_percent_of_population                                    194
# waste_collection_coverage_rural_percent_of_waste                                         209
# waste_collection_coverage_total_percent_of_geographic_area                               216
# waste_collection_coverage_total_percent_of_households                                    205
# waste_collection_coverage_total_percent_of_population                                    125
# waste_collection_coverage_total_percent_of_waste                                         167
# waste_collection_coverage_urban_percent_of_geographic_area                               216
# waste_collection_coverage_urban_percent_of_households                                    208
# waste_collection_coverage_urban_percent_of_population                                    177
# waste_collection_coverage_urban_percent_of_waste                                         208
# waste_treatment_anaerobic_digestion_percent                                              215
# waste_treatment_compost_percent                                                          149
# waste_treatment_controlled_landfill_percent                                              174
# waste_treatment_incineration_percent                                                     168
# waste_treatment_landfill_unspecified_percent                                             154
# waste_treatment_open_dump_percent                                                        149
# waste_treatment_other_percent                                                            191
# waste_treatment_recycling_percent                                                         92
# waste_treatment_sanitary_landfill_landfill_gas_system_percent                            189
# waste_treatment_unaccounted_for_percent                                                  123
# waste_treatment_waterways_marine_percent                                                 213
# where_where_is_this_data_measured                                                        160
# dtype: int64

# %%
# Drop rows with missing 'year'
country_Newdata = country_data[["iso3c","region_id","country_name","income_id","gdp","population_population_number_of_people","total_msw_total_msw_generated_tons_year","waste_treatment_open_dump_percent","waste_treatment_recycling_percent"]].copy()

country_Newdata
# Out:
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 212   XKX       ECS        Kosovo       LMC   9723.561523
# 213   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 214   ZAF       SSF  South Africa       UMC  12666.607420
# 215   ZMB       SSF        Zambia       LMC   3201.289307
# 216   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      population_population_number_of_people  \
# 0                                    103187
# 1                                  34656032
# 2                                  25096150
# 3                                   2854191
# 4                                     82431
# ..                                      ...
# 212                                 1801800
# 213                                27584212
# 214                                51729344
# 215                                14264756
# 216                                12500525
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 212                             3.190000e+05
# 213                             4.836820e+06
# 214                             1.845723e+07
# 215                             2.608268e+06
# 216                             1.449752e+06
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent
# 0                                  NaN                               11.0
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 212                              33.57                                NaN
# 213                              25.00                                8.0
# 214                                NaN                               28.0
# 215                                NaN                                NaN
# 216                                NaN                               16.0
#
# [217 rows x 9 columns]

# %%
# Check for missing values
print(country_Newdata.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 1
# income_id                                    0
# gdp                                          1
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      2
# waste_treatment_open_dump_percent          149
# waste_treatment_recycling_percent           92
# dtype: int64

# %%
country_total_data = country_Newdata.dropna(subset=["total_msw_total_msw_generated_tons_year", "country_name"],inplace=False)
# Changed the first argument to subset=["total_msw_total_msw_generated_tons_year"]
# This will drop rows where "total_msw_total_msw_generated_tons_year" has missing values
country_total_data
country_total_data
# Out:
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 212   XKX       ECS        Kosovo       LMC   9723.561523
# 213   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 214   ZAF       SSF  South Africa       UMC  12666.607420
# 215   ZMB       SSF        Zambia       LMC   3201.289307
# 216   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      population_population_number_of_people  \
# 0                                    103187
# 1                                  34656032
# 2                                  25096150
# 3                                   2854191
# 4                                     82431
# ..                                      ...
# 212                                 1801800
# 213                                27584212
# 214                                51729344
# 215                                14264756
# 216                                12500525
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 212                             3.190000e+05
# 213                             4.836820e+06
# 214                             1.845723e+07
# 215                             2.608268e+06
# 216                             1.449752e+06
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent
# 0                                  NaN                               11.0
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 212                              33.57                                NaN
# 213                              25.00                                8.0
# 214                                NaN                               28.0
# 215                                NaN                                NaN
# 216                                NaN                               16.0
#
# [214 rows x 9 columns]

# %%
print(country_total_data.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# income_id                                    0
# gdp                                          0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          146
# waste_treatment_recycling_percent           89
# dtype: int64

# %%
waste_summary = country_total_data.groupby('region_id')[['waste_treatment_open_dump_percent', 'waste_treatment_recycling_percent']].mean()
print(waste_summary)
# Out:
#            waste_treatment_open_dump_percent  \
# region_id
# EAS                                35.858571
# ECS                                66.782308
# LCN                                36.425960
# MEA                                56.692308
# NAC                                      NaN
# SAS                                70.666667
# SSF                                72.063636
#
#            waste_treatment_recycling_percent
# region_id
# EAS                                25.890476
# ECS                                24.152759
# LCN                                 7.970556
# MEA                                 9.847059
# NAC                                19.063333
# SAS                                 6.662500
# SSF                                 9.117647

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Load datasets
import pandas as pd
# Population distribution
sns.histplot(country_total_data['population_population_number_of_people'], kde=True)
plt.title('Country Population Distribution')
plt.show()

# Waste treatment percentages by income group
waste_cols = ['waste_treatment_open_dump_percent', 'waste_treatment_recycling_percent']
country_total_data.groupby('income_id')[waste_cols].mean().plot(kind='bar')
plt.title('Waste Treatment by Income Group')
plt.show()

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
fig = px.bar(country_total_data, x='region_id', y='waste_treatment_open_dump_percent', color='income_id')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4777a2f3-f178-46df-ba14-2a1545f12b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4777a2f3-f178-46df-ba14-2a1545f12b1e")) {                    Plotly.newPlot(                        "4777a2f3-f178-46df-ba14-2a1545f12b1e",                        [{"alignmentgroup":"True","hovertemplate":"income_id=HIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"HIC","offsetgroup":"HIC","orientation":"v","showlegend":true,"textposition":"auto","x":["LCN","ECS","MEA","LCN","LCN","EAS","ECS","ECS","MEA","LCN","NAC","LCN","EAS","NAC","ECS","ECS","LCN","LCN","LCN","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","EAS","EAS","ECS","ECS","ECS","ECS","ECS","MEA","ECS","EAS","LCN","EAS","MEA","ECS","ECS","ECS","ECS","EAS","LCN","ECS","MEA","EAS","EAS","ECS","ECS","EAS","MEA","LCN","EAS","ECS","LCN","ECS","EAS","MEA","MEA","EAS","ECS","ECS","ECS","ECS","SSF","LCN","LCN","NAC","LCN","LCN"],"xaxis":"x","y":[null,null,62.0,22.6,null,null,null,null,null,null,null,null,null,null,null,null,8.43,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,100.0,null,null,null,null,null,null,null,null,null,null,null,null,null,0.0,23.4,null,null,null,null,null,null,null,null,null,null,null,null,null,84.0,17.5,null,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["SAS","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","LCN","SSF","SSF","SSF","SSF","SSF","SSF","SAS","SSF","SSF","SSF","SSF","SSF","MEA","SSF","SSF","ECS","SSF","SSF","MEA","SSF"],"xaxis":"x","y":[null,null,null,59.0,null,null,null,null,43.0,null,null,null,null,null,96.7,null,99.0,null,64.0,null,null,43.8,null,null,null,80.0,null,96.2,100.0,69.0,87.0,25.0,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["SSF","SAS","LCN","SAS","SSF","SSF","SSF","SSF","MEA","MEA","EAS","ECS","SSF","LCN","EAS","SAS","SSF","ECS","EAS","EAS","EAS","SAS","SSF","MEA","ECS","EAS","EAS","SSF","SSF","LCN","SAS","EAS","EAS","MEA","SSF","EAS","LCN","SSF","SSF","EAS","MEA","ECS","ECS","EAS","EAS","ECS","SSF"],"xaxis":"x","y":[null,null,55.52,null,null,80.3,null,null,null,84.0,null,null,null,15.0,10.0,77.0,null,100.0,null,null,60.0,85.0,null,52.0,35.08,null,93.5,54.7,null,59.3,50.0,null,null,67.0,null,null,13.8,null,null,null,21.0,null,60.0,null,11.3,33.57,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_open_dump_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["ECS","ECS","EAS","ECS","ECS","ECS","ECS","LCN","LCN","SSF","EAS","LCN","LCN","LCN","LCN","LCN","MEA","LCN","EAS","SSF","SSF","LCN","LCN","LCN","MEA","MEA","LCN","MEA","ECS","MEA ...

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
fig = px.bar(country_total_data, x='region_id', y='waste_treatment_recycling_percent', color='income_id')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02aa5ba9-07f1-4049-8841-134dd6b65fe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02aa5ba9-07f1-4049-8841-134dd6b65fe2")) {                    Plotly.newPlot(                        "02aa5ba9-07f1-4049-8841-134dd6b65fe2",                        [{"alignmentgroup":"True","hovertemplate":"income_id=HIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"HIC","offsetgroup":"HIC","orientation":"v","showlegend":true,"textposition":"auto","x":["LCN","ECS","MEA","LCN","LCN","EAS","ECS","ECS","MEA","LCN","NAC","LCN","EAS","NAC","ECS","ECS","LCN","LCN","LCN","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","ECS","EAS","EAS","ECS","ECS","ECS","ECS","ECS","MEA","ECS","EAS","LCN","EAS","MEA","ECS","ECS","ECS","ECS","EAS","LCN","ECS","MEA","EAS","EAS","ECS","ECS","EAS","MEA","LCN","EAS","ECS","LCN","ECS","EAS","MEA","MEA","EAS","ECS","ECS","ECS","ECS","SSF","LCN","LCN","NAC","LCN","LCN"],"xaxis":"x","y":[11.0,null,20.0,6.0,null,42.1,25.66,34.303,8.0,null,2.0,9.0,null,20.59,32.0,28.43020231,0.37,2.0,21.0,13.31,25.5,47.83,27.27,16.84,24.74,28.12,22.26,67.0,27.25,null,19.0,null,17.85,34.0,16.32,25.94,50.0,33.0,55.81,25.0,25.9,4.9,null,58.0,null,64.6,22.92,28.37,21.23,20.0,null,5.4,6.69,36.0,null,24.61,26.16,null,26.21,null,null,26.39,14.0,16.23,39.0,3.0,15.0,61.0,45.05,7.62,46.44,32.37,null,null,8.0,34.6,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["SAS","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","SSF","LCN","SSF","SSF","SSF","SSF","SSF","SSF","SAS","SSF","SSF","SSF","SSF","SSF","MEA","SSF","SSF","ECS","SSF","SSF","MEA","SSF"],"xaxis":"x","y":[null,null,25.0,12.0,null,4.9,null,null,null,5.0,null,null,null,null,null,null,1.0,null,4.0,null,null,null,null,null,null,2.5,null,2.0,null,null,6.0,8.0,16.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["SSF","SAS","LCN","SAS","SSF","SSF","SSF","SSF","MEA","MEA","EAS","ECS","SSF","LCN","EAS","SAS","SSF","ECS","EAS","EAS","EAS","SAS","SSF","MEA","ECS","EAS","EAS","SSF","SSF","LCN","SAS","EAS","EAS","MEA","SSF","EAS","LCN","SSF","SSF","EAS","MEA","ECS","ECS","EAS","EAS","ECS","SSF"],"xaxis":"x","y":[null,null,12.11,0.86,3.0,0.4,26.2,null,null,12.5,null,null,null,null,7.0,5.0,8.0,null,null,null,10.0,12.79,null,8.0,15.32,null,null,8.0,null,null,8.0,28.0,2.0,0.5,null,null,null,null,null,null,4.0,3.2,null,23.0,37.0,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=UMC\u003cbr\u003eregion_id=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UMC","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"UMC","offsetgroup":"UMC","orientation":"v","showlegend":true,"textposition":"auto","x":["ECS","ECS","EAS","ECS","ECS","ECS","ECS","LCN","LCN","SSF","EAS","LCN","LCN","LCN","LCN","LCN","MEA","LCN","EAS","SSF","SSF","LCN","LCN","LCN","MEA","MEA","LCN","MEA","ECS"," ...

# %%
import plotly.express as px

# Example: Regional Waste Treatment Visualization
fig = px.bar(country_total_data, x='country_name', y='waste_treatment_recycling_percent', color='income_id')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="776a6f52-43f8-46b3-8c28-2d792f1f3e44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("776a6f52-43f8-46b3-8c28-2d792f1f3e44")) {                    Plotly.newPlot(                        "776a6f52-43f8-46b3-8c28-2d792f1f3e44",                        [{"alignmentgroup":"True","hovertemplate":"income_id=HIC\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HIC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"HIC","offsetgroup":"HIC","orientation":"v","showlegend":true,"textposition":"auto","x":["Aruba","Andorra","United Arab Emirates","Argentina","Antigua and Barbuda","Australia","Austria","Belgium","Bahrain","Bahamas, The","Bermuda","Barbados","Brunei Darussalam","Canada","Switzerland","Channel Islands","Chile","Curacao","Cayman Islands","Cyprus","Czech Republic","Germany","Denmark","Spain","Estonia","Finland","France","Faeroe Islands","United Kingdom","Gibraltar","Greece","Greenland","Guam","Hong Kong SAR, China","Croatia","Hungary","Isle of Man","Ireland","Iceland","Israel","Italy","Japan","St. Kitts and Nevis","Korea, Rep.","Kuwait","Liechtenstein","Lithuania","Luxembourg","Latvia","Macao SAR, China","St. Martin (French part)","Monaco","Malta","Northern Mariana Islands","New Caledonia","Netherlands","Norway","New Zealand","Oman","Panama","Palau","Poland","Puerto Rico","Portugal","French Polynesia","Qatar","Saudi Arabia","Singapore","San Marino","Slovak Republic","Slovenia","Sweden","Seychelles","Trinidad and Tobago","Uruguay","United States","British Virgin Islands","Virgin Islands (U.S.)"],"xaxis":"x","y":[11.0,null,20.0,6.0,null,42.1,25.66,34.303,8.0,null,2.0,9.0,null,20.59,32.0,28.43020231,0.37,2.0,21.0,13.31,25.5,47.83,27.27,16.84,24.74,28.12,22.26,67.0,27.25,null,19.0,null,17.85,34.0,16.32,25.94,50.0,33.0,55.81,25.0,25.9,4.9,null,58.0,null,64.6,22.92,28.37,21.23,20.0,null,5.4,6.69,36.0,null,24.61,26.16,null,26.21,null,null,26.39,14.0,16.23,39.0,3.0,15.0,61.0,45.05,7.62,46.44,32.37,null,null,8.0,34.6,null,null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LIC\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LIC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"LIC","offsetgroup":"LIC","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan","Burundi","Benin","Burkina Faso","Central African Republic","Congo, Dem. Rep.","Comoros","Eritrea","Ethiopia","Guinea","Gambia, The","Guinea-Bissau","Haiti","Liberia","Madagascar","Mali","Mozambique","Malawi","Niger","Nepal","Rwanda","Senegal","Sierra Leone","Somalia","South Sudan","Syrian Arab Republic","Chad","Togo","Tajikistan","Tanzania","Uganda","Yemen, Rep.","Zimbabwe"],"xaxis":"x","y":[null,null,25.0,12.0,null,4.9,null,null,null,5.0,null,null,null,null,null,null,1.0,null,4.0,null,null,null,null,null,null,2.5,null,2.0,null,null,6.0,8.0,16.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"income_id=LMC\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ewaste_treatment_recycling_percent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LMC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"LMC","offsetgroup":"LMC","orientation":"v","showlegend":true,"textposition":"auto","x":["Angola","Bangladesh","Bolivia","Bhutan","CÃ´te dâ€™Ivoire","Cameroon","Congo, Rep.","Cabo Verde","Djibouti","Egypt, Arab Rep.","Micronesia, Fed. Sts.","Georgia","Ghana","Honduras","Indonesia","India","Kenya","Kyrgyz Republic","Cambodia","Kiribati","Lao PDR","Sri Lanka","Lesotho","Morocco","Moldova","Myanmar","Mongoli ...

# %%
# Convert the 'total_msw_total_msw_generated_tons_year' column to numeric type before using nlargest
country_total_data["total_msw_total_msw_generated_tons_year"] = pd.to_numeric(country_total_data["total_msw_total_msw_generated_tons_year"], errors='coerce')

# Filter the top 10 cities based on total waste generated
top_countries = country_total_data.nlargest(10, "total_msw_total_msw_generated_tons_year")

# Dynamically adjust the figure size based on the number of cities
plt.figure(figsize=(max(15, len(top_cities) / 2), 8))  # Adjust width dynamically

# Plot the bar chart
plt.bar(top_countries["country_name"], top_countries["total_msw_total_msw_generated_tons_year"], color='orange')

# Customize the plot
plt.xticks(rotation=90, fontsize=10)  # Rotate X-axis labels for better readability
plt.xlabel("Country Name", fontsize=14)
plt.ylabel("Total MSW Generated (tons/Year)", fontsize=14)
plt.title("Waste Generated by Top 10 Countries", fontsize=16)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()
# Out:
# <ipython-input-268-77f07417ba66>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert the 'total_msw_total_msw_generated_tons_year' column to numeric type before using nsmallest
country_total_data["total_msw_total_msw_generated_tons_year"] = pd.to_numeric(
    country_total_data["total_msw_total_msw_generated_tons_year"], errors="coerce"
)

# Filter the bottom 10 countries based on total waste generated
bottom_countries = country_total_data.nsmallest(10, "total_msw_total_msw_generated_tons_year")

# Dynamically adjust the figure size based on the number of countries
plt.figure(figsize=(max(15, len(bottom_countries) / 2), 8))  # Adjust width dynamically

# Plot the bar chart
plt.bar(bottom_countries["country_name"], bottom_countries["total_msw_total_msw_generated_tons_year"], color="green")

# Customize the plot
plt.xticks(rotation=90, fontsize=10)  # Rotate X-axis labels for better readability
plt.xlabel("Country Name", fontsize=14)
plt.ylabel("Total MSW Generated (tons/Year)", fontsize=14)
plt.title("Waste Generated by Bottom 10 Countries", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Display the plot
plt.show()
# Out:
# <ipython-input-269-48b94c520a95>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
country_total_data["gdp per capita"] = country_total_data["gdp"] / country_total_data["population_population_number_of_people"]
country_total_data
# Out:
# <ipython-input-270-f2dba0f7784d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 212   XKX       ECS        Kosovo       LMC   9723.561523
# 213   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 214   ZAF       SSF  South Africa       UMC  12666.607420
# 215   ZMB       SSF        Zambia       LMC   3201.289307
# 216   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      population_population_number_of_people  \
# 0                                    103187
# 1                                  34656032
# 2                                  25096150
# 3                                   2854191
# 4                                     82431
# ..                                      ...
# 212                                 1801800
# 213                                27584212
# 214                                51729344
# 215                                14264756
# 216                                12500525
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 212                             3.190000e+05
# 213                             4.836820e+06
# 214                             1.845723e+07
# 215                             2.608268e+06
# 216                             1.449752e+06
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent  \
# 0                                  NaN                               11.0
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 212                              33.57                                NaN
# 213                              25.00                                8.0
# 214                                NaN                               28.0
# 215                                NaN                                NaN
# 216                                NaN                               16.0
#
#      gdp per capita
# 0          0.344649
# 1          0.000059
# 2          0.000320
# 3          0.004808
# 4          0.530284
# ..              ...
# 212        0.005397
# 213        0.000300
# 214        0.000245
# 215        0.000224
# 216        0.000255
#
# [214 rows x 10 columns]

# %%
print(country_total_data.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# income_id                                    0
# gdp                                          0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          146
# waste_treatment_recycling_percent           89
# gdp per capita                               0
# dtype: int64

# %%
country_codebook
# Out:
#      regionID iso3c    country_name incomeID  \
# 0         EAS   ASM  American Samoa      UMC
# 1         EAS   ASM  American Samoa      UMC
# 2         EAS   ASM  American Samoa      UMC
# 3         EAS   ASM  American Samoa      UMC
# 4         EAS   ASM  American Samoa      UMC
# ...       ...   ...             ...      ...
# 3771      SSF   ZWE        Zimbabwe      LIC
# 3772      SSF   ZWE        Zimbabwe      LIC
# 3773      SSF   ZWE        Zimbabwe      LIC
# 3774      SSF   ZWE        Zimbabwe      LIC
# 3775      SSF   ZWE        Zimbabwe      LIC
#
#                                             measurement  \
# 0                composition_food_organic_waste_percent
# 1                             composition_glass_percent
# 2                             composition_metal_percent
# 3                             composition_other_percent
# 4                   composition_paper_cardboard_percent
# ...                                                 ...
# 3771  waste_collection_coverage_total_percent_of_pop...
# 3772   waste_collection_coverage_total_percent_of_waste
# 3773                      waste_treatment_other_percent
# 3774                  waste_treatment_recycling_percent
# 3775            waste_treatment_unaccounted_for_percent
#
#                       units    year  \
# 0                         %  2011.0
# 1                         %  2011.0
# 2                         %  2011.0
# 3                         %  2011.0
# 4                         %  2011.0
# ...                     ...     ...
# 3771  Percent of households  2013.0
# 3772  Percent of households  2013.0
# 3773                      %  2015.0
# 3774            tonnes/year  2005.0
# 3775            tonnes/year     NaN
#
#                                                  source  \
# 0     SPREP (Secretariat of the Pacific Regional Env...
# 1     SPREP (Secretariat of the Pacific Regional Env...
# 2     SPREP (Secretariat of the Pacific Regional Env...
# 3     SPREP (Secretariat of the Pacific Regional Env...
# 4     SPREP (Secretariat of the Pacific Regional Env...
# ...                                                 ...
# 3771  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3772  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3773  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3774  AFED (Arab Forum for Environment and Developme...
# 3775                                                NaN
#
#                                                comments Unnamed: 9
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3     7; 8; 9; other includes disposable diaper (5.5...        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 3771                                                NaN        NaN
# 3772                                                NaN        NaN
# 3773                                                  1        NaN
# 3774                                                NaN        NaN
# 3775                                                NaN        NaN
#
# [3776 rows x 10 columns]

# %%
print(country_codebook.isnull().sum())
# Out:
# regionID           0
# iso3c              0
# country_name      17
# incomeID           0
# measurement        0
# units              0
# year              72
# source            74
# comments        3178
# Unnamed: 9      3774
# dtype: int64

# %%
country_Newcodebook = country_codebook.dropna(subset=["country_name","year"], inplace=False)
# Changed the first argument to subset=["total_msw_total_msw_generated_tons_year"]
# This will drop rows where "total_msw_total_msw_generated_tons_year" has missing values
country_Newcodebook
# Out:
#      regionID iso3c    country_name incomeID  \
# 0         EAS   ASM  American Samoa      UMC
# 1         EAS   ASM  American Samoa      UMC
# 2         EAS   ASM  American Samoa      UMC
# 3         EAS   ASM  American Samoa      UMC
# 4         EAS   ASM  American Samoa      UMC
# ...       ...   ...             ...      ...
# 3770      SSF   ZWE        Zimbabwe      LIC
# 3771      SSF   ZWE        Zimbabwe      LIC
# 3772      SSF   ZWE        Zimbabwe      LIC
# 3773      SSF   ZWE        Zimbabwe      LIC
# 3774      SSF   ZWE        Zimbabwe      LIC
#
#                                             measurement  \
# 0                composition_food_organic_waste_percent
# 1                             composition_glass_percent
# 2                             composition_metal_percent
# 3                             composition_other_percent
# 4                   composition_paper_cardboard_percent
# ...                                                 ...
# 3770  waste_collection_coverage_total_percent_of_hou...
# 3771  waste_collection_coverage_total_percent_of_pop...
# 3772   waste_collection_coverage_total_percent_of_waste
# 3773                      waste_treatment_other_percent
# 3774                  waste_treatment_recycling_percent
#
#                       units    year  \
# 0                         %  2011.0
# 1                         %  2011.0
# 2                         %  2011.0
# 3                         %  2011.0
# 4                         %  2011.0
# ...                     ...     ...
# 3770  Percent of households  2013.0
# 3771  Percent of households  2013.0
# 3772  Percent of households  2013.0
# 3773                      %  2015.0
# 3774            tonnes/year  2005.0
#
#                                                  source  \
# 0     SPREP (Secretariat of the Pacific Regional Env...
# 1     SPREP (Secretariat of the Pacific Regional Env...
# 2     SPREP (Secretariat of the Pacific Regional Env...
# 3     SPREP (Secretariat of the Pacific Regional Env...
# 4     SPREP (Secretariat of the Pacific Regional Env...
# ...                                                 ...
# 3770  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3771  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3772  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3773  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3774  AFED (Arab Forum for Environment and Developme...
#
#                                                comments Unnamed: 9
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3     7; 8; 9; other includes disposable diaper (5.5...        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 3770                                                NaN        NaN
# 3771                                                NaN        NaN
# 3772                                                NaN        NaN
# 3773                                                  1        NaN
# 3774                                                NaN        NaN
#
# [3687 rows x 10 columns]

# %%
country_finalcodebook = country_Newcodebook.iloc[:,0:7]
country_finalcodebook
# Out:
#      regionID iso3c    country_name incomeID  \
# 0         EAS   ASM  American Samoa      UMC
# 1         EAS   ASM  American Samoa      UMC
# 2         EAS   ASM  American Samoa      UMC
# 3         EAS   ASM  American Samoa      UMC
# 4         EAS   ASM  American Samoa      UMC
# ...       ...   ...             ...      ...
# 3770      SSF   ZWE        Zimbabwe      LIC
# 3771      SSF   ZWE        Zimbabwe      LIC
# 3772      SSF   ZWE        Zimbabwe      LIC
# 3773      SSF   ZWE        Zimbabwe      LIC
# 3774      SSF   ZWE        Zimbabwe      LIC
#
#                                             measurement  \
# 0                composition_food_organic_waste_percent
# 1                             composition_glass_percent
# 2                             composition_metal_percent
# 3                             composition_other_percent
# 4                   composition_paper_cardboard_percent
# ...                                                 ...
# 3770  waste_collection_coverage_total_percent_of_hou...
# 3771  waste_collection_coverage_total_percent_of_pop...
# 3772   waste_collection_coverage_total_percent_of_waste
# 3773                      waste_treatment_other_percent
# 3774                  waste_treatment_recycling_percent
#
#                       units    year
# 0                         %  2011.0
# 1                         %  2011.0
# 2                         %  2011.0
# 3                         %  2011.0
# 4                         %  2011.0
# ...                     ...     ...
# 3770  Percent of households  2013.0
# 3771  Percent of households  2013.0
# 3772  Percent of households  2013.0
# 3773                      %  2015.0
# 3774            tonnes/year  2005.0
#
# [3687 rows x 7 columns]

# %%
# Drop rows with missing 'year' and "country_name"
country_Year_codebook = country_finalcodebook.dropna(subset=["year","country_name"],inplace=False)
country_Year_codebook
# Out:
#      regionID iso3c    country_name incomeID  \
# 0         EAS   ASM  American Samoa      UMC
# 1         EAS   ASM  American Samoa      UMC
# 2         EAS   ASM  American Samoa      UMC
# 3         EAS   ASM  American Samoa      UMC
# 4         EAS   ASM  American Samoa      UMC
# ...       ...   ...             ...      ...
# 3770      SSF   ZWE        Zimbabwe      LIC
# 3771      SSF   ZWE        Zimbabwe      LIC
# 3772      SSF   ZWE        Zimbabwe      LIC
# 3773      SSF   ZWE        Zimbabwe      LIC
# 3774      SSF   ZWE        Zimbabwe      LIC
#
#                                             measurement  \
# 0                composition_food_organic_waste_percent
# 1                             composition_glass_percent
# 2                             composition_metal_percent
# 3                             composition_other_percent
# 4                   composition_paper_cardboard_percent
# ...                                                 ...
# 3770  waste_collection_coverage_total_percent_of_hou...
# 3771  waste_collection_coverage_total_percent_of_pop...
# 3772   waste_collection_coverage_total_percent_of_waste
# 3773                      waste_treatment_other_percent
# 3774                  waste_treatment_recycling_percent
#
#                       units    year
# 0                         %  2011.0
# 1                         %  2011.0
# 2                         %  2011.0
# 3                         %  2011.0
# 4                         %  2011.0
# ...                     ...     ...
# 3770  Percent of households  2013.0
# 3771  Percent of households  2013.0
# 3772  Percent of households  2013.0
# 3773                      %  2015.0
# 3774            tonnes/year  2005.0
#
# [3687 rows x 7 columns]

# %%
print(country_Year_codebook.isnull().sum())
# Out:
# regionID        0
# iso3c           0
# country_name    0
# incomeID        0
# measurement     0
# units           0
# year            0
# dtype: int64

# %%
# Convert the "year" column to integers
country_Year_codebook['year'] = country_Year_codebook['year'].astype(int)

country_Year_codebook
# Out:
#      regionID iso3c    country_name incomeID  \
# 0         EAS   ASM  American Samoa      UMC
# 1         EAS   ASM  American Samoa      UMC
# 2         EAS   ASM  American Samoa      UMC
# 3         EAS   ASM  American Samoa      UMC
# 4         EAS   ASM  American Samoa      UMC
# ...       ...   ...             ...      ...
# 3770      SSF   ZWE        Zimbabwe      LIC
# 3771      SSF   ZWE        Zimbabwe      LIC
# 3772      SSF   ZWE        Zimbabwe      LIC
# 3773      SSF   ZWE        Zimbabwe      LIC
# 3774      SSF   ZWE        Zimbabwe      LIC
#
#                                             measurement  \
# 0                composition_food_organic_waste_percent
# 1                             composition_glass_percent
# 2                             composition_metal_percent
# 3                             composition_other_percent
# 4                   composition_paper_cardboard_percent
# ...                                                 ...
# 3770  waste_collection_coverage_total_percent_of_hou...
# 3771  waste_collection_coverage_total_percent_of_pop...
# 3772   waste_collection_coverage_total_percent_of_waste
# 3773                      waste_treatment_other_percent
# 3774                  waste_treatment_recycling_percent
#
#                       units  year
# 0                         %  2011
# 1                         %  2011
# 2                         %  2011
# 3                         %  2011
# 4                         %  2011
# ...                     ...   ...
# 3770  Percent of households  2013
# 3771  Percent of households  2013
# 3772  Percent of households  2013
# 3773                      %  2015
# 3774            tonnes/year  2005
#
# [3687 rows x 7 columns]

# %%
# Filter rows based on the "units" column
tonnes_data1 = country_Year_codebook[country_Year_codebook['measurement'] == 'total_msw_total_msw_generated_tons_year']
tonnes_data1
# Out:
#      regionID iso3c       country_name incomeID  \
# 7         EAS   ASM     American Samoa      UMC
# 27        EAS   AUS          Australia      HIC
# 43        EAS   BRN  Brunei Darussalam      HIC
# 61        EAS   CHN              China      UMC
# 85        EAS   FJI               Fiji      UMC
# ...       ...   ...                ...      ...
# 3709      SSF   TZA           Tanzania      LIC
# 3720      SSF   UGA             Uganda      LIC
# 3737      SSF   ZAF       South Africa      UMC
# 3751      SSF   ZMB             Zambia      LMC
# 3768      SSF   ZWE           Zimbabwe      LIC
#
#                                   measurement        units  year
# 7     total_msw_total_msw_generated_tons_year  tonnes/year  2016
# 27    total_msw_total_msw_generated_tons_year  tonnes/year  2015
# 43    total_msw_total_msw_generated_tons_year  tonnes/year  2016
# 61    total_msw_total_msw_generated_tons_year  tonnes/year  2019
# 85    total_msw_total_msw_generated_tons_year  tonnes/year  2011
# ...                                       ...          ...   ...
# 3709  total_msw_total_msw_generated_tons_year  tonnes/year  2012
# 3720  total_msw_total_msw_generated_tons_year  tonnes/year  2011
# 3737  total_msw_total_msw_generated_tons_year  tonnes/year  2011
# 3751  total_msw_total_msw_generated_tons_year  tonnes/year  2011
# 3768  total_msw_total_msw_generated_tons_year  tonnes/year  2002
#
# [215 rows x 7 columns]

# %%
print(tonnes_data1.isnull().sum())
# Out:
# regionID        0
# iso3c           0
# country_name    0
# incomeID        0
# measurement     0
# units           0
# year            0
# dtype: int64

# %%
import pandas as pd

# Perform the merge on common columns
country_com_codebook = pd.merge(
    country_total_data,
    tonnes_data1[["country_name", "year"]],  # Only keep necessary columns from tonnes_data
    how="left",  # Left join to keep all rows from city_com_data
    on="country_name"  # Merge on city_name
)

# Check the resulting table
country_com_codebook
# Out:
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 209   XKX       ECS        Kosovo       LMC   9723.561523
# 210   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 211   ZAF       SSF  South Africa       UMC  12666.607420
# 212   ZMB       SSF        Zambia       LMC   3201.289307
# 213   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      population_population_number_of_people  \
# 0                                    103187
# 1                                  34656032
# 2                                  25096150
# 3                                   2854191
# 4                                     82431
# ..                                      ...
# 209                                 1801800
# 210                                27584212
# 211                                51729344
# 212                                14264756
# 213                                12500525
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 209                             3.190000e+05
# 210                             4.836820e+06
# 211                             1.845723e+07
# 212                             2.608268e+06
# 213                             1.449752e+06
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent  \
# 0                                  NaN                               11.0
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 209                              33.57                                NaN
# 210                              25.00                                8.0
# 211                                NaN                               28.0
# 212                                NaN                                NaN
# 213                                NaN                               16.0
#
#      gdp per capita    year
# 0          0.344649  2013.0
# 1          0.000059  2016.0
# 2          0.000320  2012.0
# 3          0.004808  2019.0
# 4          0.530284  2012.0
# ..              ...     ...
# 209        0.005397  2015.0
# 210        0.000300  2016.0
# 211        0.000245  2011.0
# 212        0.000224  2011.0
# 213        0.000255  2002.0
#
# [214 rows x 11 columns]

# %%
# Check for missing values
print(country_com_codebook.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# income_id                                    0
# gdp                                          0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          146
# waste_treatment_recycling_percent           89
# gdp per capita                               0
# year                                         1
# dtype: int64

# %%
# Drop rows where "year" is NaN
country_com_codebook = country_com_codebook.dropna(subset=["year"])

# Convert the "year" column to integers
country_com_codebook['year'] = country_com_codebook['year'].astype(int)

country_com_codebook
# Out:
# <ipython-input-274-c6442edd4001>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 209   XKX       ECS        Kosovo       LMC   9723.561523
# 210   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 211   ZAF       SSF  South Africa       UMC  12666.607420
# 212   ZMB       SSF        Zambia       LMC   3201.289307
# 213   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      population_population_number_of_people  \
# 0                                    103187
# 1                                  34656032
# 2                                  25096150
# 3                                   2854191
# 4                                     82431
# ..                                      ...
# 209                                 1801800
# 210                                27584212
# 211                                51729344
# 212                                14264756
# 213                                12500525
#
#      total_msw_total_msw_generated_tons_year  \
# 0                               8.813202e+04
# 1                               5.628525e+06
# 2                               4.213644e+06
# 3                               1.087447e+06
# 4                               4.300000e+04
# ..                                       ...
# 209                             3.190000e+05
# 210                             4.836820e+06
# 211                             1.845723e+07
# 212                             2.608268e+06
# 213                             1.449752e+06
#
#      waste_treatment_open_dump_percent  waste_treatment_recycling_percent  \
# 0                                  NaN                               11.0
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 209                              33.57                                NaN
# 210                              25.00                                8.0
# 211                                NaN                               28.0
# 212                                NaN                                NaN
# 213                                NaN                               16.0
#
#      gdp per capita  year
# 0          0.344649  2013
# 1          0.000059  2016
# 2          0.000320  2012
# 3          0.004808  2019
# 4          0.530284  2012
# ..              ...   ...
# 209        0.005397  2015
# 210        0.000300  2016
# 211        0.000245  2011
# 212        0.000224  2011
# 213        0.000255  2002
#
# [213 rows x 11 columns]

# %%
# Check for missing values
print(country_com_codebook.isnull().sum())
# Out:
# iso3c                                        0
# region_id                                    0
# country_name                                 0
# income_id                                    0
# gdp                                          0
# population_population_number_of_people       0
# total_msw_total_msw_generated_tons_year      0
# waste_treatment_open_dump_percent          145
# waste_treatment_recycling_percent           89
# gdp per capita                               0
# year                                         0
# dtype: int64

# %%
# Trend analysis for a specific metric
yearly_trend = country_com_codebook.groupby('year')['waste_treatment_open_dump_percent'].mean()
yearly_trend.plot()
plt.title('Country Waste Treatment open_dump Trends Over Time')
plt.show()

# %%
# Trend analysis for a specific metric
yearly_trend = country_com_codebook.groupby('year')['waste_treatment_recycling_percent'].mean()
yearly_trend.plot()
plt.title('Country Waste Treatment recycling Trends Over Time')
plt.show()

# %%
# Save the file to Google Drive
#merged_total_data.to_csv('/content/drive/My Drive/merged_total_data.csv',encoding='cp1252',index=False)

# %%
city_com_codebook.head()
# Out:
#   iso3c region_id country_name       city_name income_id  \
# 0   AFG       SAS  Afghanistan       Jalalabad       LIC
# 1   AFG       SAS  Afghanistan        Kandahar       LIC
# 2   AFG       SAS  Afghanistan  Mazar-E-Sharif       LIC
# 3   AFG       SAS  Afghanistan           Kabul       LIC
# 5   AGO       SSF       Angola          Luanda       LMC
#
#    population_population_number_of_people  \
# 0                                326585.0
# 1                                429000.0
# 2                                635250.0
# 3                               3700000.0
# 5                               4508000.0
#
#    total_msw_total_msw_generated_tons_year  msw per capita  year
# 0                                 58914.45        0.180395  2017
# 1                                120971.00        0.281984  2017
# 2                                 52368.40        0.082437  2017
# 3                               1989250.00        0.537635  2016
# 5                               1316336.00        0.292000  2009

# %%
city_com_codebook1 = city_com_codebook.iloc[:,[2,3,7]]
city_com_codebook1
# Out:
#     country_name       city_name  msw per capita
# 0    Afghanistan       Jalalabad        0.180395
# 1    Afghanistan        Kandahar        0.281984
# 2    Afghanistan  Mazar-E-Sharif        0.082437
# 3    Afghanistan           Kabul        0.537635
# 5         Angola          Luanda        0.292000
# ..           ...             ...             ...
# 320       Zambia          Lusaka        0.308319
# 321     Zimbabwe          Norton        0.240000
# 322     Zimbabwe        Chinhoyi        0.260000
# 324     Zimbabwe           Gweru        0.240000
# 325     Zimbabwe          Kariba        0.280000
#
# [303 rows x 3 columns]

# %%
country_com_codebook.head()
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC  35563.312500
# 1   AFG       SAS  Afghanistan       LIC   2057.062256
# 2   AGO       SSF       Angola       LMC   8036.690430
# 3   ALB       ECS      Albania       UMC  13724.058590
# 4   AND       ECS      Andorra       HIC  43711.800780
#
#    population_population_number_of_people  \
# 0                                  103187
# 1                                34656032
# 2                                25096150
# 3                                 2854191
# 4                                   82431
#
#    total_msw_total_msw_generated_tons_year  waste_treatment_open_dump_percent  \
# 0                             8.813202e+04                                NaN
# 1                             5.628525e+06                                NaN
# 2                             4.213644e+06                                NaN
# 3                             1.087447e+06                                NaN
# 4                             4.300000e+04                                NaN
#
#    waste_treatment_recycling_percent  gdp per capita  year
# 0                               11.0        0.344649  2013
# 1                                NaN        0.000059  2016
# 2                                NaN        0.000320  2012
# 3                                NaN        0.004808  2019
# 4                                NaN        0.530284  2012

# %%
country_com_codebook1 = country_com_codebook.iloc[:,[2,9]]
country_com_codebook1
# Out:
#      country_name  gdp per capita
# 0           Aruba        0.344649
# 1     Afghanistan        0.000059
# 2          Angola        0.000320
# 3         Albania        0.004808
# 4         Andorra        0.530284
# ..            ...             ...
# 209        Kosovo        0.005397
# 210   Yemen, Rep.        0.000300
# 211  South Africa        0.000245
# 212        Zambia        0.000224
# 213      Zimbabwe        0.000255
#
# [213 rows x 2 columns]

# %%
import pandas as pd

# Ensure the 'country_name' column exists in both tables
# Merge the tables on the 'country_name' column
merged_table = pd.merge(city_com_codebook1, country_com_codebook1, on="country_name", how="inner")

# Display the result
merged_table
# Out:
#     country_name       city_name  msw per capita  gdp per capita
# 0    Afghanistan       Jalalabad        0.180395        0.000059
# 1    Afghanistan        Kandahar        0.281984        0.000059
# 2    Afghanistan  Mazar-E-Sharif        0.082437        0.000059
# 3    Afghanistan           Kabul        0.537635        0.000059
# 4         Angola          Luanda        0.292000        0.000320
# ..           ...             ...             ...             ...
# 297       Zambia          Lusaka        0.308319        0.000224
# 298     Zimbabwe          Norton        0.240000        0.000255
# 299     Zimbabwe        Chinhoyi        0.260000        0.000255
# 300     Zimbabwe           Gweru        0.240000        0.000255
# 301     Zimbabwe          Kariba        0.280000        0.000255
#
# [302 rows x 4 columns]

# %%
# Check for missing values
print(merged_table.isnull().sum())
# Out:
# country_name      0
# city_name         0
# msw per capita    0
# gdp per capita    0
# dtype: int64

# %%
# Example Analysis: Correlation between GDP per capita and MSW per capita
correlation = merged_table["gdp per capita"].corr(merged_table["msw per capita"])
print(f"Correlation between GDP per capita and MSW per capita: {correlation}")

# Optional: Visualization
import matplotlib.pyplot as plt

plt.scatter(merged_table["gdp per capita"], merged_table["msw per capita"], color='gold')
plt.title("Correlation")
plt.xlabel("GDP per Capita")
plt.ylabel("MSW per Capita")
plt.grid()
plt.show()
# Out:
# Correlation between GDP per capita and MSW per capita: 0.054692152148378206
